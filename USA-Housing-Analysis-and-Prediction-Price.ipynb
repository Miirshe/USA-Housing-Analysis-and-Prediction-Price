# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Processing Of Machine Learning Life Cycle
#
# ### `Data Gathering`
# ###  `Data Preparation`
# ### `Data Wrangling `
# ### `Data Analysis`
# ### `Train Model`
# ### `Test Model`
# ### `Paper`

# %%
usa_housing = pd.read_csv('USA_Housing.csv')

# %%
usa_housing
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA) Functions

# %%
# Returns the column names of the DataFrame.
usa_housing.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
# Returns the dimensions (rows, columns) of the DataFrame
usa_housing.shape
# Out:
# (5000, 7)

# %%
# Displays the first 5 rows of the DataFrame.
# Display top 5 structure of data columns and rows 
usa_housing.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# Displays basic information about the DataFrame, including data types and non-null values
# Display basic information about the dataset
usa_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# Removes duplicate rows from the DataFrame.
# Removed duplicate values
usa_housing = usa_housing.drop_duplicates()

# %%
# Dislay shape o dataset
usa_housing.shape[0]
# Out:
# 5000

# %%
# Checks for missing values in the DataFrame.
# Check for any missing values
usa_housing.isnull().isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
# Displays summary statistics (mean, std, min, max, etc.) for numerical columns.
# Display summary statistics
usa_housing.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ### Display the count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum

# %%
# display descriptive statistics for entire dataset
usa_housing_desc_stat = usa_housing.describe()
print(usa_housing_desc_stat)
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ### Additional statistics for categorical variables

# %%
# display additional statistics for categorical  variables
categorical_stat = usa_housing.describe(include='O')
# describe method can take optional parameter knowns us include 
# include '0' stands for object (categorical variable)
print(categorical_stat)
# Out:
#                                                   Address
# count                                                5000
# unique                                               5000
# top     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# freq                                                    1

# %% [markdown]
# ### Now, we provide verbal comments on some of the key statistics and justifications for our choices made:

# %% [markdown]
# * **'Count':** Represents the number of non-null entries for each variable. It indicates if there are missing values in the dataset.
#
# * **'Mean':** Represents the average value of each variable. It gives you a central measure around which the data tends to cluster.
#
# * **'Std (Standard Deviation)':** Measures the amount of variation or dispersion in the data. A higher standard deviation indicates greater variability.
#
# * **'Min and Max':** Show the minimum and maximum values in each variable. These values help identify the range of the data.
#
# * **'25th, 50th (Median), and 75th percentiles':** Indicate the values below which a given percentage of observations fall. The median is the 50th percentile and represents the middle value.

# %% [markdown]
# # Create visualizations for numerical variables using Matplotlib

# %%
# defines list numerical variables 
columns =  ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
                 'Avg. Area Number of Bedrooms', 'Area Population', 'Price']
# defines list colors of each variable
colors = [
    "lightcoral","lightgreen","lightpink","lightpink","lightblue","orange"
]

# set up subplot
fig ,axes = plt.subplots(nrows=2, ncols = 3 , figsize = (15,8))
fig.suptitle ('Distributions of Numerical Variables')

for i , (col , color ) in enumerate(zip(columns , colors)):
    axes[i // 3 , i % 3].hist(usa_housing[col], bins=20, color=color, edgecolor='black')
    axes[i // 3 , i % 3].set_title(col)
    axes[i // 3 , i % 3].set_xlabel(col)
    axes[i // 3 , i % 3].set_ylabel('Frequency')
    
# Adjust layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# show plots    
plt.show()

# %%
# Pairplot displays for numeric variables
sns.pairplot(usa_housing)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\hp\AppData\Local\Temp\ipykernel_21332\2760872749.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.hist(usa_housing['Price'], bins=20, color=color, edgecolor='black')
plt.xlabel('before log transform ')  # Corrected line
plt.title('Histogram before log transform')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
from scipy.stats import zscore

# Calculate Z-scores for each column
z_scores = zscore(usa_housing.select_dtypes(include='float'))

# Define a threshold for Z-scores (e.g., 3)
threshold = 3  

# Filter rows where any Z-score exceeds the threshold
outliers = (z_scores > threshold).any(axis=1)

# Remove outliers
usa_housing = usa_housing[outliers]
data =  usa_housing.drop(['Address'], axis = 1 )
plt.figure(figsize = (15,8))
sns.heatmap(data.corr(), annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.hist(usa_housing['Price'], bins=20, color=color, edgecolor='black')
plt.xlabel('before log transform ')  # Corrected line
plt.title('Histogram before log transform')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

x = usa_housing.drop(['Price','Address'], axis = 1 )
y = usa_housing['Price']

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 228        66574.70999             5.550265                   6.844150
# 256        91159.41833             6.536045                   7.373851
# 353        72445.03330             5.488197                   6.509449
# 465        90592.46961             7.700132                   9.708803
# 693       107701.74840             7.143522                   8.518608
# 924        83814.10116             8.571797                   7.392164
# 962       101928.85810             4.829586                   9.039382
# 1091       75358.48260             8.991399                   7.282680
# 1234       63785.55128             7.196314                   6.357874
# 1248       94733.97128             7.885829                   7.162373
# 1536       69505.11151             7.352350                  10.759588
# 1595       64350.28457             6.761203                   7.128710
# ...

# %%
y
# Out:
# 228     1702406.039
# 256     2298379.487
# 353     1726719.067
# 465     2469065.594
# 693     2332110.740
# 924     2330289.701
# 962     1938866.490
# 1091    1740404.967
# 1234    1747244.863
# 1248    2318285.703
# 1536    2235294.718
# 1595    1772390.553
# 1734    1742431.663
# 1777    1468267.230
# 1891    2007556.286
# 2066    2050594.046
# 2173    1168588.031
# 2538    2294647.784
# 2719    2370231.320
# 2839    2130762.000
# 2898    1561313.838
# 3134    1737570.505
# 3138    1898168.684
# 3336    2065710.164
# 3541    1754937.715
# 3806    1311432.388
# 3855    1810158.487
# 3989    1399906.450
# 3991    1626676.490
# 4087    1644923.078
# 4716    1267986.688
# 4803    1504315.619
# Name: Price, dtype: float64

# %%
# Split the data into training and testing sets
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
data_train = x_train.join(y_train)

# %%
data_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 256        91159.41833             6.536045                   7.373851
# 3806       53230.11971             6.274360                  10.024375
# 4087      100741.29860             5.870726                   6.644853
# 3541      102881.12090             6.471249                   5.693536
# 353        72445.03330             5.488197                   6.509449
# 2066       79057.79892             7.634776                  10.219902
# 2719      101599.67060             7.798746                   7.480512
# 465        90592.46961             7.700132                   9.708803
# 3134       74112.79329             4.412585                   8.054622
# 1891      101144.32390             6.350845                   7.231771
# 3855       68449.04732             8.390376                  10.144988
# 1248       94733.97128             7.885829                   7.162373
# ...

# %%
data_train.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Rooms'}>,
#         <Axes: title={'center': 'Avg. Area Number of Bedrooms'}>],
#        [<Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data_train.corr(), annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
usa_housing['Address'].value_counts()
# Out:
# Address
# 551 Macdonald Viaduct\nWest Stephanie, TN 55360                   1
# 170 Smith Wall\nSouth Christopherhaven, AZ 87521                  1
# 14763 Jeffrey Islands\nAmytown, WV 47279-7543                     1
# 5155 Virginia Station\nFischerberg, PA 75078-8129                 1
# 300 Jamie Freeway\nSouth Marioshire, MI 12514-5439                1
# 96381 Sonya Mission\nEast Kevin, OK 68218-3510                    1
# 46215 Craig Causeway Suite 574\nJoyport, DC 81001-1533            1
# 71718 Barrett Ramp\nCaseybury, NH 91777-4042                      1
# 784 Arnold Prairie Apt. 787\nJamesside, NM 04270                  1
# Unit 8831 Box 5748\nDPO AE 73012-7314                             1
# 969 Robert Vista Suite 545\nWest Kelly, NC 31856-7083             1
# 04976 Joel Plaza Suite 658\nSouth Dominiqueland, MS 27646-5758    1
# 854 Brown Park Apt. 787\nNew Alexander, NH 99886                  1
# 50114 Wendy Road\nJoelport, OR 96203-3217                         1
# ...

# %%
data_train['Avg. Area Number of Rooms'] = np.log(data_train['Avg. Area Number of Rooms'] + 1)
data_train['Avg. Area Number of Bedrooms'] = np.log(data_train['Avg. Area Number of Bedrooms'] + 1)
data_train['Area Population'] = np.log(data_train['Area Population'] + 1)

# %%
data_train.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Rooms'}>,
#         <Axes: title={'center': 'Avg. Area Number of Bedrooms'}>],
#        [<Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
data_train['bedromm_ratio'] = data_train['Avg. Area Number of Bedrooms'] / data_train['Avg. Area Number of Rooms']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data_train.corr(), annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
# Initialize the linear regression model
model = LinearRegression()

# Train the model
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 5234417194.621949
# R-squared: 0.93231876334102

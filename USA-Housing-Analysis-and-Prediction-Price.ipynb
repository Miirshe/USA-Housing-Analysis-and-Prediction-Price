# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
usa_housing = pd.read_csv('USA_Housing.csv')

# %%
usa_housing
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09      23086.80050  1.059034e+06
# 1                             3.09      40173.07217  1.505891e+06
# 2                             5.13      36882.15940  1.058988e+06
# 3                             3.26      34310.24283  1.260617e+06
# 4                             4.23      26354.10947  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46      22837.36103  1.060194e+06
# 4996                          4.02      25616.11549  1.482618e+06
# 4997                          2.13      33266.14549  1.030730e+06
# 4998                          5.44      42625.62016  1.198657e+06
# 4999                          4.07      46501.28380  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
usa_housing.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
usa_housing.shape
# Out:
# (5000, 7)

# %%
usa_housing.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
usa_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
usa_housing = usa_housing.drop_duplicates()

# %%
usa_housing.shape[0]
# Out:
# 5000

# %%
usa_housing.isnull().isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
usa_housing.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928700  9.975771e+05
# 50%                        4.050000     36199.406690  1.232669e+06
# 75%                        4.490000     42861.290770  1.471210e+06
# max                        6.500000     69621.713380  2.469066e+06

# %%
usa_housing
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09      23086.80050  1.059034e+06
# 1                             3.09      40173.07217  1.505891e+06
# 2                             5.13      36882.15940  1.058988e+06
# 3                             3.26      34310.24283  1.260617e+06
# 4                             4.23      26354.10947  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46      22837.36103  1.060194e+06
# 4996                          4.02      25616.11549  1.482618e+06
# 4997                          2.13      33266.14549  1.030730e+06
# 4998                          5.44      42625.62016  1.198657e+06
# 4999                          4.07      46501.28380  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

x = usa_housing.drop(['Price'], axis = 1 )
y = usa_housing['Price']

# %%
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population  \
# 0                             4.09      23086.80050
# 1                             3.09      40173.07217
# 2                             5.13      36882.15940
# 3                             3.26      34310.24283
# 4                             4.23      26354.10947
# ...                            ...              ...
# 4995                          3.46      22837.36103
# 4996                          4.02      25616.11549
# 4997                          2.13      33266.14549
# 4998                          5.44      42625.62016
# 4999                          4.07      46501.28380
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 6 columns]

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
data_train = x_train.join(y_train)

# %%
data_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2110       77079.71716             4.255009                   6.528580
# 4757       56030.47489             5.029915                   7.932589
# 123        74384.10563             7.411487                   5.164865
# 433        66484.04819             4.825804                   9.069530
# 2307       71713.79826             6.446438                   7.845240
# ...                ...                  ...                        ...
# 3453       57852.03331             5.690224                   7.287616
# 4002       78685.83503             7.020023                   7.368314
# 1650       60028.08245             5.121561                   6.173060
# 1493       57169.41546             5.959289                   6.373969
# 4820       50442.26643             4.767998                   7.248288
#
#       Avg. Area Number of Bedrooms  Area Population  \
# 2110                          2.39      32236.82469
# 4757                          3.19      46255.54143
# 123                           2.30      17117.44367
# 433                           3.37      51712.14409
# 2307                          6.15      26861.13336
# ...                            ...              ...
# 3453                          6.18      42688.46134
# 4002                          5.14      34767.78842
# 1650                          3.29      36651.51947
# 1493                          4.36      47966.91683
# 4820                          6.07      33439.80668
#
#                                                 Address         Price
# 2110  459 Foley Parkways Apt. 307\nAndrewtown, KY 41233  1.018458e+06
# 4757        4959 Roth Ferry\nPort Robert, KY 90147-8962  8.870170e+05
# 123   757 Sherri Shores Suite 744\nJesusfurt, OK 730...  1.200539e+06
# 433   5035 Daniel Port Suite 074\nPort Jordanbury, S...  1.511743e+06
# 2307        5672 Barton Port\nGonzalesborough, PR 77884  1.361829e+06
# ...                                                 ...           ...
# 3453            269 Kelley Ford\nMiaport, MS 72773-0985  1.197069e+06
# 4002                495 Hill Green\nEast Kyle, SC 87017  1.672445e+06
# 1650  7891 Amber Springs Suite 295\nEast Jonathansta...  8.422358e+05
# 1493  14455 Jackson Point Apt. 513\nDavisside, ND 07...  1.176655e+06
# 4820    0645 Arroyo Trail\nEast Michelle, LA 07906-8981  6.441425e+05
#
# [4000 rows x 7 columns]

# %%
data_train.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Rooms'}>,
#         <Axes: title={'center': 'Avg. Area Number of Bedrooms'}>],
#        [<Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data_train.corr(), annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
usa_housing['Address'].value_counts()
# Out:
# Address
# 208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101             1
# 314 Christopher Square Apt. 404\nLake Ronaldville, SD 42025      1
# 21042 Wilson Islands Suite 238\nFischerchester, MP 42425-4129    1
# Unit 8831 Box 5748\nDPO AE 73012-7314                            1
# 481 Kaitlin Mission Apt. 309\nJodystad, IA 16947                 1
#                                                                 ..
# 054 Carter Crescent Suite 674\nGlennport, WA 11140               1
# 8460 Kathleen Mission Apt. 482\nPort Amytown, KY 72016           1
# 3737 Hartman Rue\nReneestad, ID 69250-7718                       1
# 3465 Latoya Well\nNelsonmouth, MI 55741-4287                     1
# 37778 George Ridges Apt. 509\nEast Holly, NV 29290-3595          1
# Name: count, Length: 5000, dtype: int64

# %%
data_train['Avg. Area Number of Rooms'] = np.log(data_train['Avg. Area Number of Rooms'] + 1)
data_train['Avg. Area Number of Bedrooms'] = np.log(data_train['Avg. Area Number of Bedrooms'] + 1)
data_train['Area Population'] = np.log(data_train['Area Population'] + 1)

# %%
data_train.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>,
#         <Axes: title={'center': 'Avg. Area Number of Rooms'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Bedrooms'}>,
#         <Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Bedroom'}>,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
data_train['bedromm_ratio'] = data_train['Avg. Area Number of Bedrooms'] / data_train['Avg. Area Number of Rooms']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(data_train.corr(), annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

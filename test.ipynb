# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
semesters = ['semester_1','semester_2','semester_3','semester_4','semester_6']
mark_average = [65,70,75,80,85,90,95,100]
np_semesters = np.array(semesters)

# %%
np_semesters
# Out:
# array(['semester_1', 'semester_2', 'semester_3', 'semester_4',
#        'semester_6'], dtype='<U10')

# %%
np_mark_average = np.array(mark_average)

# %%
np_mark_average
# Out:
# array([ 65,  70,  75,  80,  85,  90,  95, 100])

# %%
plt.plot(np_mark_average,np_mark_average, color='red',linestyle='-')
plt.title('mark average semesters')
plt.xlabel('mark averages')
plt.ylabel('semesters')
plt.show()
